# %%
pip install -r requirements.txt
# Out:
# Requirement already satisfied: sentence-transformers in c:\users\mprem\anaconda3\lib\site-packages (from -r requirements.txt (line 1)) (5.0.0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: pinecone-client in c:\users\mprem\anaconda3\lib\site-packages (from -r requirements.txt (line 2)) (6.0.0)
# Requirement already satisfied: requests in c:\users\mprem\anaconda3\lib\site-packages (from -r requirements.txt (line 3)) (2.32.3)
# Requirement already satisfied: schedule in c:\users\mprem\anaconda3\lib\site-packages (from -r requirements.txt (line 4)) (1.2.2)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in c:\users\mprem\anaconda3\lib\site-packages (from sentence-transformers->-r requirements.txt (line 1)) (4.53.2)
# Requirement already satisfied: tqdm in c:\users\mprem\anaconda3\lib\site-packages (from sentence-transformers->-r requirements.txt (line 1)) (4.66.5)
# Requirement already satisfied: torch>=1.11.0 in c:\users\mprem\anaconda3\lib\site-packages (from sentence-transformers->-r requirements.txt (line 1)) (2.7.1)
# Requirement already satisfied: scikit-learn in c:\users\mprem\anaconda3\lib\site-packages (from sentence-transformers->-r requirements.txt (line 1)) (1.5.1)
# Requirement already satisfied: scipy in c:\users\mprem\anaconda3\lib\site-packages (from sentence-transformers->-r requirements.txt (line 1)) (1.13.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in c:\users\mprem\anaconda3\lib\site-packages (from sentence-transformers->-r requirements.txt (line 1)) (0.33.4)
# Requirement already satisfied: Pillow in c:\users\mprem\anaconda3\lib\site-packages (from sentence-transformers->-r requirements.txt (line 1)) (10.4.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\users\mprem\anaconda3\lib\site-packages (from sentence-transformers->-r requirements.txt (line 1)) (4.11.0)
# Requirement already satisfied: certifi>=2019.11.17 in c:\users\mprem\anaconda3\lib\site-packages (from pinecone-client->-r requirements.txt (line 2)) (2025.4.26)
# Requirement already satisfied: pinecone-plugin-interface<0.0.8,>=0.0.7 in c:\users\mprem\anaconda3\lib\site-packages (from pinecone-client->-r requirements.txt (line 2)) (0.0.7)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\mprem\anaconda3\lib\site-packages (from pinecone-client->-r requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: urllib3>=1.26.5 in c:\users\mprem\anaconda3\lib\site-packages (from pinecone-client->-r requirements.txt (line 2)) (1.26.20)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\mprem\anaconda3\lib\site-packages (from requests->-r requirements.txt (line 3)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mprem\anaconda3\lib\site-packages (from requests->-r requirements.txt (line 3)) (3.7)
# Requirement already satisfied: filelock in c:\users\mprem\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers->-r requirements.txt (line 1)) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\mprem\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers->-r requirements.txt (line 1)) (2024.6.1)
# Requirement already satisfied: packaging>=20.9 in c:\users\mprem\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers->-r requirements.txt (line 1)) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\mprem\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers->-r requirements.txt (line 1)) (6.0.1)
# Requirement already satisfied: six>=1.5 in c:\users\mprem\anaconda3\lib\site-packages (from python-dateutil>=2.5.3->pinecone-client->-r requirements.txt (line 2)) (1.16.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\mprem\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers->-r requirements.txt (line 1)) (1.14.0)
# Requirement already satisfied: networkx in c:\users\mprem\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers->-r requirements.txt (line 1)) (3.3)
# Requirement already satisfied: jinja2 in c:\users\mprem\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers->-r requirements.txt (line 1)) (3.1.4)
# Requirement already satisfied: setuptools in c:\users\mprem\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers->-r requirements.txt (line 1)) (75.1.0)
# Requirement already satisfied: colorama in c:\users\mprem\anaconda3\lib\site-packages (from tqdm->sentence-transformers->-r requirements.txt (line 1)) (0.4.6)
# Requirement already satisfied: numpy>=1.17 in c:\users\mprem\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers->-r requirements.txt (line 1)) (1.26.4)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\mprem\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers->-r requirements.txt (line 1)) (2024.9.11)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in c:\users\mprem\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers->-r requirements.txt (line 1)) (0.21.2)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\mprem\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers->-r requirements.txt (line 1)) (0.5.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\mprem\anaconda3\lib\site-packages (from scikit-learn->sentence-transformers->-r requirements.txt (line 1)) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\mprem\anaconda3\lib\site-packages (from scikit-learn->sentence-transformers->-r requirements.txt (line 1)) (3.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\mprem\anaconda3\lib\site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers->-r requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\mprem\anaconda3\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers->-r requirements.txt (line 1)) (2.1.3)

# %%
import requests
from datetime import datetime, timezone
from sentence_transformers import SentenceTransformer
from pinecone import Pinecone, ServerlessSpec
import schedule
import time

# ========================
# CONFIGURATION
# ========================
PINECONE_API_KEY = "pcsk_6e4xVY_Cyg5dTpVDnq1VczBX6PmPfX6264qWAH8Gur7PGqc9kigACZSNAAFdsN18HG5asp"
INDEX_NAME = "wikipedia-knowledge"

# Wikipedia topics to track
WIKI_TOPICS = [
    "Artificial_intelligence",
    "Machine_learning",
    "Space_exploration",
    "Climate_change",
    "Python_(programming_language)"
]

# ========================
# INITIALIZE
# ========================
model = SentenceTransformer("all-MiniLM-L6-v2")
pc = Pinecone(api_key=PINECONE_API_KEY)

# Create index if not exists
if INDEX_NAME not in [idx["name"] for idx in pc.list_indexes()]:
    pc.create_index(
        name=INDEX_NAME,
        dimension=384,  # embedding size for all-MiniLM-L6-v2
        metric="cosine",
        spec=ServerlessSpec(cloud="aws", region="us-east-1")
    )

index = pc.Index(INDEX_NAME)

# ========================
# FUNCTIONS
# ========================
def fetch_wikipedia_summary(topic):
    """Fetch summary text for a given Wikipedia topic."""
    url = f"https://en.wikipedia.org/api/rest_v1/page/summary/{topic}"
    try:
        r = requests.get(url, timeout=10)
        r.raise_for_status()
        data = r.json()
        return data.get("extract", ""), data.get("content_urls", {}).get("desktop", {}).get("page", "")
    except Exception as e:
        print(f"⚠ Error fetching {topic}: {e}")
        return "", ""

def update_knowledge():
    print("🔄 Running update pipeline...")
    for topic in WIKI_TOPICS:
        text, source_url = fetch_wikipedia_summary(topic)
        if text:
            embedding = model.encode(text).tolist()
            now = datetime.now(timezone.utc).isoformat()
            index.upsert([
                {
                    "id": f"{topic}-{now}",
                    "values": embedding,
                    "metadata": {
                        "topic": topic,
                        "source": source_url,
                        "text": text,
                        "time": now
                    }
                }
            ])
    print("✅ Update complete.")

def search_knowledge(query, top_k=3):
    """Search for relevant Wikipedia summaries in Pinecone."""
    query_embedding = model.encode(query).tolist()
    results = index.query(vector=query_embedding, top_k=top_k, include_metadata=True)
    return [
        {
            "topic": match["metadata"]["topic"],
            "source": match["metadata"]["source"],
            "text": match["metadata"]["text"],
            "time": match["metadata"]["time"]
        }
        for match in results["matches"]
    ]

# ========================
# SCHEDULER: update every hour
# ========================
schedule.every(1).hours.do(update_knowledge)

# Run once at startup
update_knowledge()

# ========================
# INTERACTIVE CHAT LOOP
# ========================
while True:
    schedule.run_pending()
    user_input = input("\nAsk me something (type 'exit' to quit): ")
    if user_input.lower() in ["exit", "quit"]:
        break

    results = search_knowledge(user_input, top_k=1)
    if results:
        res = results[0]
        print(f"\nTopic: {res['topic']}")
        print(f"Source: {res['source']}")
        print(f"Text snippet: {res['text'][:500]}...")
    else:
        print("No results found.")
# Out:
# 🔄 Running update pipeline...
# ✅ Update complete.
# Ask me something (type 'exit' to quit):  what is python
# Topic: Python_(programming_language)
# Source: https://en.wikipedia.org/wiki/Python_(programming_language)
# Text snippet: Python is a high-level, general-purpose programming language. Its design philosophy emphasizes code readability with the use of significant indentation....
# Ask me something (type 'exit' to quit):  exit
